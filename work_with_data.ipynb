# %%
import os
import pandas as pd
import shutil
#Читаю обучающий файл 
train=pd.read_csv(r'D:\dataset_mp3\a_cvs_info\train.csv',  sep="\t", encoding="utf-8")
#Вывожу таблицу
train_labels=train[["path", "age", "gender"]]
train_labels
# Out:
#                                path       age  gender
# 0      common_voice_ru_19921774.mp3  thirties    male
# 1      common_voice_ru_21289707.mp3  twenties  female
# 2      common_voice_ru_21565172.mp3  twenties    male
# 3      common_voice_ru_20209182.mp3  thirties    male
# 4      common_voice_ru_20664775.mp3  twenties    male
# ...                             ...       ...     ...
# 63671  common_voice_ru_19563401.mp3  fourties    male
# 63672  common_voice_ru_19563402.mp3  fourties    male
# 63673  common_voice_ru_19563403.mp3  fourties    male
# 63674  common_voice_ru_19563404.mp3  fourties    male
# 63675  common_voice_ru_19563405.mp3  fourties    male
#
# [63676 rows x 3 columns]

# %%
male_train = train_labels[train_labels["gender"]=="male"] #выбираю файлы в train.csv, которые имеют gender == male
female_train = train_labels[train_labels["gender"]=="female"]

#выбираю файлы вида male/fifties и female/fifties 
female_fifties_train = female_train[female_train["age"]=="fifties"] 
male_fifties_train = male_train[male_train["age"]=="fifties"]

male_sixties_train = male_train[male_train["age"]=="sixties"]
female_sixties_train = female_train[female_train["age"]=="sixties"]

female_thirties_train = female_train[female_train["age"]=="thirties"]
male_thirties_train = male_train[male_train["age"]=="thirties"]

female_twenties_train = female_train[female_train["age"]=="twenties"]
male_twenties_train = male_train[male_train["age"]=="twenties"]

female_teens_train = female_train[female_train["age"]=="teens"]
male_teens_train = male_train[male_train["age"]=="teens"]

female_fourties_train = female_train[female_train["age"]=="fourties"]
male_fourties_train = male_train[male_train["age"]=="fourties"]

male_fourties_train
# Out:
#                                path       age gender
# 48     common_voice_ru_20184553.mp3  fourties   male
# 49     common_voice_ru_20184556.mp3  fourties   male
# 50     common_voice_ru_20184554.mp3  fourties   male
# 51     common_voice_ru_20184552.mp3  fourties   male
# 52     common_voice_ru_20541359.mp3  fourties   male
# ...                             ...       ...    ...
# 63671  common_voice_ru_19563401.mp3  fourties   male
# 63672  common_voice_ru_19563402.mp3  fourties   male
# 63673  common_voice_ru_19563403.mp3  fourties   male
# 63674  common_voice_ru_19563404.mp3  fourties   male
# 63675  common_voice_ru_19563405.mp3  fourties   male
#
# [11743 rows x 3 columns]

# %%
paths = os.listdir('D:/image')
#перекидываю из общей папки изображения в директорию train/male 
for f in male_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/gender/male/"+ f) 


#теперь train >> train/female
for f in female_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/gender/female/"+ f)

# %%
# train >> fifties
for f in male_fifties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/male_fifties/"+ f)
    
for f in female_fifties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/female_fifties/"+ f)

# %%
# train >> sixties
for f in male_sixties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/male_sixties/"+ f)
    
for f in female_sixties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/female_sixties/"+ f)

# %%
# train >> thirties
for f in male_thirties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/male_thirties/"+ f)
    
for f in female_thirties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/female_thirties/"+ f)

# %%
# train >> twenties
for f in male_twenties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/male_twenties/"+ f)
    
for f in female_twenties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/female_twenties/"+ f)

# %%
# train >> teens
for f in male_teens_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/male_teens/"+ f)
    
for f in female_teens_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/female_teens/"+ f)

# %%
# train >> fourties
for f in male_fourties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/male_fourties/"+ f)
    
for f in female_fourties_train["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/train/age/female_fourties/"+ f)

# %%
#Теперь читаю тестовый файл
test=pd.read_csv(r'D:\dataset_mp3\a_cvs_info\test.csv',  sep="\t", encoding="utf-8")
#Вывожу таблицу
test_labels=test[["path", "age", "gender"]]
test_labels
# Out:
#                                path       age gender
# 0      common_voice_ru_19573600.mp3   fifties   male
# 1      common_voice_ru_19573598.mp3   fifties   male
# 2      common_voice_ru_19573601.mp3   fifties   male
# 3      common_voice_ru_19121569.mp3   sixties   male
# 4      common_voice_ru_19121568.mp3   sixties   male
# ...                             ...       ...    ...
# 13235  common_voice_ru_19417272.mp3  fourties   male
# 13236  common_voice_ru_19563299.mp3  fourties   male
# 13237  common_voice_ru_19563327.mp3  fourties   male
# 13238  common_voice_ru_19563382.mp3  fourties   male
# 13239  common_voice_ru_19563404.mp3  fourties   male
#
# [13240 rows x 3 columns]

# %%
male_test = test_labels[test_labels["gender"]=="male"] #выбираю файлы в test.csv, которые имеют gender == male
female_test  = test_labels[test_labels["gender"]=="female"]

#выбираю файлы вида male/fifties и female/fifties 
female_fifties_test  = female_test[female_test ["age"]=="fifties"] 
male_fifties_test  = male_test[male_test ["age"]=="fifties"]

male_sixties_test  = male_test [male_test ["age"]=="sixties"]
female_sixties_test  = female_test [female_test ["age"]=="sixties"]

female_thirties_test  = female_test [female_test ["age"]=="thirties"]
male_thirties_test  = male_test [male_test ["age"]=="thirties"]

female_twenties_test  = female_test [female_test ["age"]=="twenties"]
male_twenties_test  = male_test [male_test ["age"]=="twenties"]

female_teens_test  = female_test [female_test ["age"]=="teens"]
male_teens_test  = male_test [male_test ["age"]=="teens"]

female_fourties_test  = female_test [female_test ["age"]=="fourties"]
male_fourties_test  = male_test [male_test ["age"]=="fourties"]

male_teens_test
# Out:
#                                path    age gender
# 529    common_voice_ru_20227589.mp3  teens   male
# 530    common_voice_ru_20227593.mp3  teens   male
# 531    common_voice_ru_20227592.mp3  teens   male
# 532    common_voice_ru_20227590.mp3  teens   male
# 533    common_voice_ru_20227599.mp3  teens   male
# ...                             ...    ...    ...
# 10759  common_voice_ru_21650094.mp3  teens   male
# 10760  common_voice_ru_21650092.mp3  teens   male
# 10761  common_voice_ru_21650106.mp3  teens   male
# 10762  common_voice_ru_21650149.mp3  teens   male
# 10763  common_voice_ru_21650195.mp3  teens   male
#
# [2032 rows x 3 columns]

# %%
paths = os.listdir('D:/image')
#перекидываю из общей папки изображения в директорию test/male 
for f in male_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/gender/male/"+ f)


#теперь test >> train/female
for f in female_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/gender/female/"+ f)

# %%
# test >> fifties
for f in male_fifties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/male_fifties/"+ f)
    
for f in female_fifties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/female_fifties/"+ f)

# %%
for f in male_sixties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/male_sixties/"+ f)
    
for f in female_sixties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/female_sixties/"+ f)

# %%
for f in male_thirties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/male_thirties/"+ f)
    
for f in female_thirties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/female_thirties/"+ f)

# %%
for f in male_twenties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/male_twenties/"+ f)
    
for f in female_twenties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/female_twenties/"+ f)

# %%
for f in male_teens_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/male_teens/"+ f)
    
for f in female_teens_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/female_teens/"+ f)

# %%
for f in male_fourties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/male_fourties/"+ f)
    
for f in female_fourties_test["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/test/age/female_fourties/"+ f)

# %%
#Теперь читаю validated файл
val=pd.read_csv(r'D:\dataset_mp3\a_cvs_info\val.csv',  sep="\t", encoding="utf-8")
#Вывожу таблицу
val_labels=val[["path", "age", "gender"]]
val_labels
# Out:
#                               path       age  gender
# 0     common_voice_ru_19921774.mp3  thirties    male
# 1     common_voice_ru_21289707.mp3  twenties  female
# 2     common_voice_ru_21565172.mp3  twenties    male
# 3     common_voice_ru_20209182.mp3  thirties    male
# 4     common_voice_ru_20664775.mp3  twenties    male
# ...                            ...       ...     ...
# 4378  common_voice_ru_18934919.mp3   fifties  female
# 4379  common_voice_ru_18952959.mp3   fifties  female
# 4380  common_voice_ru_18937594.mp3  fourties    male
# 4381  common_voice_ru_18937799.mp3  fourties    male
# 4382  common_voice_ru_19028620.mp3  twenties    male
#
# [4383 rows x 3 columns]

# %%
male_val = val_labels[val_labels["gender"]=="male"] #выбираю файлы в val.csv, которые имеют gender == male
female_val  = val_labels[val_labels["gender"]=="female"]

#выбираю файлы вида male/fifties и female/fifties 
female_fifties_val  = female_val [female_val ["age"]=="fifties"] 
male_fifties_val  = male_val[male_val ["age"]=="fifties"]

male_sixties_val  = male_val [male_val ["age"]=="sixties"]
female_sixties_val  = female_val[female_val ["age"]=="sixties"]

female_thirties_val  = female_val [female_val ["age"]=="thirties"]
male_thirties_val  = male_val[male_val["age"]=="thirties"]

female_twenties_val  = female_val [female_val ["age"]=="twenties"]
male_twenties_val  = male_val[male_val ["age"]=="twenties"]

female_teens_val  = female_val[female_val ["age"]=="teens"]
male_teens_val = male_val[male_val ["age"]=="teens"]

female_fourties_val  = female_val [female_val ["age"]=="fourties"]
male_fourties_val = male_val [male_val ["age"]=="fourties"]

male_sixties_val
# Out:
#                               path      age gender
# 338   common_voice_ru_19121569.mp3  sixties   male
# 339   common_voice_ru_19121568.mp3  sixties   male
# 340   common_voice_ru_19121574.mp3  sixties   male
# 341   common_voice_ru_19121571.mp3  sixties   male
# 342   common_voice_ru_19121567.mp3  sixties   male
# 862   common_voice_ru_19058899.mp3  sixties   male
# 863   common_voice_ru_19058903.mp3  sixties   male
# 864   common_voice_ru_19058901.mp3  sixties   male
# 865   common_voice_ru_19058902.mp3  sixties   male
# 866   common_voice_ru_19058930.mp3  sixties   male
# 867   common_voice_ru_19058934.mp3  sixties   male
# 868   common_voice_ru_19058933.mp3  sixties   male
# 869   common_voice_ru_19058936.mp3  sixties   male
# 870   common_voice_ru_19058938.mp3  sixties   male
# 3388  common_voice_ru_20506560.mp3  sixties   male
# 3389  common_voice_ru_20506541.mp3  sixties   male
# 3390  common_voice_ru_20506542.mp3  sixties   male
# 3391  common_voice_ru_20506544.mp3  sixties   male
# 3392  common_voice_ru_20506543.mp3  sixties   male
# 3393  common_voice_ru_20506549.mp3  sixties   male
# 3394  common_voice_ru_20506550.mp3  sixties   male
# 3395  common_voice_ru_20506547.mp3  sixties   male
# 3396  common_voice_ru_20506559.mp3  sixties   male
# 3397  common_voice_ru_20506554.mp3  sixties   male
# 3398  common_voice_ru_20506555.mp3  sixties   male
# 3399  common_voice_ru_20506553.mp3  sixties   male
# 3400  common_voice_ru_20506557.mp3  sixties   male
# 3401  common_voice_ru_20506552.mp3  sixties   male
# 3402  common_voice_ru_20506545.mp3  sixties   male
# 3403  common_voice_ru_20506551.mp3  sixties   male
# 3404  common_voice_ru_20506566.mp3  sixties   male
# 3405  common_voice_ru_20506569.mp3  sixties   male
# 3406  common_voice_ru_20506570.mp3  sixties   male
# 3407  common_voice_ru_20506567.mp3  sixties   male
# 3408  common_voice_ru_20506568.mp3  sixties   male
# 3409  common_voice_ru_20506593.mp3  sixties   male
# 3410  common_voice_ru_20506594.mp3  sixties   male
# 3411  common_voice_ru_20506595.mp3  sixties   male
# 3412  common_voice_ru_20506596.mp3  sixties   male
# 3413  common_voice_ru_20524872.mp3  sixties   male
# 3414  common_voice_ru_20524871.mp3  sixties   male
# 3415  common_voice_ru_20524875.mp3  sixties   male
# 3416  common_voice_ru_20524874.mp3  sixties   male
# 3417  common_voice_ru_20524892.mp3  sixties   male
# 3418  common_voice_ru_20524896.mp3  sixties   male
# 3419  common_voice_ru_20524915.mp3  sixties   male
# 3420  common_voice_ru_20524912.mp3  sixties   male
# 3421  common_voice_ru_20524894.mp3  sixties   male
# 3422  common_voice_ru_20524913.mp3  sixties   male
# 3423  common_voice_ru_20524895.mp3  sixties   male
# 3424  common_voice_ru_20524921.mp3  sixties   male
# 3425  common_voice_ru_20524923.mp3  sixties   male
# 3426  common_voice_ru_20524925.mp3  sixties   male
# 3427  common_voice_ru_20524922.mp3  sixties   male

# %%
paths = os.listdir('D:/image')
#перекидываю из общей папки изображения в директорию val/male 
for f in male_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/gender/male/"+ f)
paths = os.listdir('D:/image') 


#теперь val/female
for f in female_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/gender/female/"+ f)

# %%
# val >> fifties
for f in male_fifties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/male_fifties/"+ f)
    
for f in female_fifties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/female_fifties/"+ f)

# %%
for f in male_sixties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/male_sixties/"+ f)
    
for f in female_sixties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/female_sixties/"+ f)

# %%
for f in male_thirties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/male_thirties/"+ f)
    
for f in female_thirties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/female_thirties/"+ f)

# %%
for f in male_twenties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/male_twenties/"+ f)
    
for f in female_twenties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/female_twenties/"+ f)

# %%
for f in male_teens_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/male_teens/"+ f)
    
for f in female_teens_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/female_teens/"+ f)

# %%
for f in male_fourties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/male_fourties/"+ f)
    
for f in female_fourties_val["path"].tolist():
  f = f.replace('.mp3', '.wav.png')
  if f in paths:
    shutil.copy('D:/image/' + f, "D:/val/age/female_fourties/"+ f)
