# %%
import pandas as pd
import numpy as np


#test(4383)


#train(13189) 


#validate (63676)

# %%
test = pd.read_csv(r'D:\test.tsv', sep="\t", header=0, encoding="utf-8")
#читаем файл
del test['sentence']
del test['up_votes']
del test['down_votes']
del test['locale']
del test['segment']
del test['accent']
del test['client_id']
#удаляем столбцы
test = test.dropna(axis = 0, how = 'any')
test = test[test["gender"] != 'other']
#удаляем все строки, у которых в столбцах есть NaN, и удаляем пол 'other'
test.to_csv('D:/test_ready.csv', index=False, sep="\t")
#сохраняем файл в csv без индексов

# %%
train = pd.read_csv(r'D:\train.tsv', sep="\t", header=0, encoding="utf-8")
#читаем файл
del train['sentence']
del train['up_votes']
del train['down_votes']
del train['locale']
del train['segment']
del train['accent']
del train['client_id']
#удаляем столбцы
train = train.dropna(axis = 0, how = 'any')
train = train[train["gender"] != 'other']
#удаляем все строки, у которых в столбцах есть NaN
train.to_csv('D:/train_ready.csv', index=False, sep="\t")
#сохраняем файл в csv без индексов

# %%
validated = pd.read_csv(r'D:\validated.tsv', sep="\t", header=0, encoding="utf-8", low_memory=False)
#читаем файл
del validated['sentence']
del validated['up_votes']
del validated['down_votes']
del validated['locale']
del validated['segment']
del validated['accent']
del validated['client_id']
#удаляем столбцы
validated = validated.dropna(axis = 0, how = 'any')
validated = validated[validated["gender"] != 'other']
#удаляем все строки, у которых в столбцах есть NaN
validated.to_csv('D:/validated_ready.csv', index=False, sep="\t")
#сохраняем файл в csv без индексов

# %%
validated_update = pd.read_csv(r'D:\validated_ready.csv', sep="\t", header=0, encoding="utf-8", low_memory=False)
validated_update = validated_update.dropna(axis = 0, how = 'any')
# удаляю из validated.csv файлы перекинутые в train.csv
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19573600.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19573598.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19573601.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19121569.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19121568.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19121574.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19121571.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19121567.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21818877.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21818878.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21818876.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21818879.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21818880.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21818952.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21818954.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21818955.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21818953.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058899.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058900.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058903.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058901.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058902.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058930.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058934.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058933.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058936.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_19058938.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981646.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981647.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981648.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981650.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981649.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981666.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981668.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981670.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981669.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981676.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981680.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981677.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981678.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_18981679.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20992885.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20992888.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20992884.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20992882.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20992887.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20996142.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20996143.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20996144.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20996140.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_20996141.mp3']
validated_update = validated_update[validated_update["path"] != 'common_voice_ru_21081683.mp3']
#сохраняю
validated.to_csv('D:/validated_full_ready.csv', index=False, sep="\t")

# %%
#файл из перекидываемых файлов
to_train = pd.read_csv('D:/validated_to_train.csv', sep="\t")
train = pd.read_csv(r'D:\train_ready.csv', sep="\t", header=0, encoding="utf-8")
#совмещаю данные в to_train в train
train_full_ready_update = pd.concat([to_train, train], ignore_index=True)
#сохраняю окончательный вариант
train_full_ready_update.to_csv('D:/train_full_ready_update.csv', index=False, sep="\t")
